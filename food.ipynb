# %% [markdown]
# Data is at https://fdc.nal.usda.gov/download-datasets.html: See "Foundation Foods - April 2020 (CSV – 2.3M)". Read "Download_Field....pdf" for details. Some relevant details from the PDF:
# branded_food table = Foods whose nutrient values are typically obtained from food label data
# provided by food brand owners.
#
#
# I want to model this project after https://www.kaggle.com/arthurtok/super-sized-we-mcdonald-s-nutritional-metrics.

# %%
import pandas
foods = pandas.read_csv('data/food.csv')
foods.head()
# Out:
#    fdc_id           data_type            description  food_category_id  \
# 0  319875  market_acquisition  HUMMUS, SABRA CLASSIC              16.0
# 1  319876  market_acquisition  HUMMUS, SABRA CLASSIC              16.0
# 2  319880  market_acquisition  HUMMUS, SABRA CLASSIC              16.0
# 3  319881  market_acquisition  HUMMUS, SABRA CLASSIC              16.0
# 4  319886  market_acquisition  HUMMUS, SABRA CLASSIC              16.0
#
#   publication_date
# 0       2019-04-01
# 1       2019-04-01
# 2       2019-04-01
# 3       2019-04-01
# 4       2019-04-01

# %%
foods.food_category_id.value_counts(dropna=False)
# Out:
#  1.0     6406
#  11.0    2274
#  9.0     1963
#  5.0     1503
#  16.0    1202
#  15.0     913
#  7.0      795
#  10.0     613
#  6.0      568
#  18.0     488
#  25.0     474
#  13.0     454
#  20.0     448
#  4.0      414
#  2.0      386
#  12.0     267
#  19.0      54
# NaN        22
# Name: food_category_id, dtype: int64

# %%
foods[foods.food_category_id==1].description.value_counts().head()
# Out:
# Eggs, whole              242
# BUTTER, STICK, SALTED    205
# EGGS, GRADE A, LARGE     201
# MILK, WHOLE              180
# MILK, SKIM               178
# Name: description, dtype: int64

# %%
foods[foods.food_category_id==2].description.value_counts().head()
# Out:
# Salt; iodized                 73
# SALT, MORTON, IODIZED         24
# Salt, Iodized                 16
# SALT, GREAT VALUE, IODIZED    10
# Salt, Not Iodized              5
# Name: description, dtype: int64

# %%
food_attributes = pandas.read_csv('data/food_attribute.csv')
food_attributes
# Out:
#           id  fdc_id  seq_num  food_attribute_type_id      name  \
# 0       5578  323121      0.0                    1000       NaN
# 1       5579  327046      0.0                    1000       NaN
# 2       5580  333476      0.0                    1000       NaN
# 3       5581  334247      0.0                    1000       NaN
# 4       5582  334849      0.0                    1000       NaN
# 5       5583  334897      0.0                    1000       NaN
# 6       5584  334898      0.0                    1000       NaN
# 7       5585  334963      0.0                    1000       NaN
# 8       5586  335061      0.0                    1000       NaN
# 9       5587  335109      0.0                    1000       NaN
# 10    290889  746758      NaN                    1000       NaN
# 11    290890  746759      NaN                    1000       NaN
# 12    290891  746760      NaN                    1000       NaN
# 13    290892  746761      NaN                    1000       NaN
# ...

# %%
nutrients = pandas.read_csv('data/food_nutrient.csv')
nutrients.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id  fdc_id  nutrient_id  amount  data_points  derivation_id   min  \
# 0  2219707  321358         1120     3.0          1.0            1.0   NaN
# 1  2219708  321358         1122     0.0          1.0            1.0   NaN
# 2  2219709  321358         1127     1.3          6.0            1.0  0.26
# 3  2219710  321358         1130     0.0          6.0            1.0  0.00
# 4  2219711  321358         1131     0.0          6.0            1.0  0.00
#
#     max  median footnote  min_year_acquired
# 0   NaN    3.00      NaN             2015.0
# 1   NaN    0.00      NaN             2015.0
# 2  2.47    1.21      NaN             2015.0
# 3  0.00    0.00      NaN             2015.0
# 4  0.00    0.00      NaN             2015.0

# %%
food[food.fdc_id==319875]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ca5cfaf1faa2> in <module>()
# ----> 1 food[food.fdc_id==319875]
#
# NameError: name 'food' is not defined

# %%
nutrients[nutrients.fdc_id==319875]
# Out:
# Empty DataFrame
# Columns: [id, fdc_id, nutrient_id, amount, data_points, derivation_id, min, max, median, footnote, min_year_acquired]
# Index: []

# %%
food[food.fdc_id==321358]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-83d538debd18> in <module>()
# ----> 1 food[food.fdc_id==321358]
#
# NameError: name 'food' is not defined

# %%
nutrients[nutrients.fdc_id==321358]
# Out:
#           id  fdc_id  nutrient_id  amount  data_points  derivation_id     min  \
# 0    2219707  321358         1120   3.000          1.0            1.0     NaN
# 1    2219708  321358         1122   0.000          1.0            1.0     NaN
# 2    2219709  321358         1127   1.300          6.0            1.0   0.260
# 3    2219710  321358         1130   0.000          6.0            1.0   0.000
# 4    2219711  321358         1131   0.000          6.0            1.0   0.000
# 5    2219712  321358         1162   0.000          6.0            1.0   0.000
# 6    2219713  321358         1165   0.150          6.0            1.0   0.120
# 7    2219714  321358         1166   0.115          6.0            1.0   0.080
# 8    2219715  321358         1177  36.000          6.0            1.0  13.000
# 9    2219716  321358         1184   0.000          2.0            1.0   0.000
# 10   2219717  321358         1185  17.200          2.0            1.0  11.200
# ...

# %%
food_nutrients = nutrients.merge(foods, left_on='fdc_id', right_on='fdc_id')
food_nutrients.head()
# Out:
#         id  fdc_id  nutrient_id  amount  data_points  derivation_id   min  \
# 0  2219707  321358         1120     3.0          1.0            1.0   NaN
# 1  2219708  321358         1122     0.0          1.0            1.0   NaN
# 2  2219709  321358         1127     1.3          6.0            1.0  0.26
# 3  2219710  321358         1130     0.0          6.0            1.0  0.00
# 4  2219711  321358         1131     0.0          6.0            1.0  0.00
#
#     max  median footnote  min_year_acquired        data_type  \
# 0   NaN    3.00      NaN             2015.0  foundation_food
# 1   NaN    0.00      NaN             2015.0  foundation_food
# 2  2.47    1.21      NaN             2015.0  foundation_food
# 3  0.00    0.00      NaN             2015.0  foundation_food
# 4  0.00    0.00      NaN             2015.0  foundation_food
#
#           description  food_category_id publication_date
# 0  Hummus, commercial              16.0       2019-04-01
# ...

# %%
food_nutrients.nutrient_id.value_counts()
# Out:
# 1051    2554
# 1004    2525
# 1090    2259
# 1098    2259
# 1091    2258
# 1101    2258
# 1087    2257
# 1095    2257
# 1089    2253
# 1092    2246
# 1007    1650
# 1002    1439
# 1093    1391
# 1003    1132
# 1079    1122
# 1009    1022
# 1102     892
# 1265     880
# 1264     880
# 1266     880
# 1315     869
# 1314     869
# 1316     862
# 1267     855
# 1300     855
# 1301     850
# 1406     848
# 1299     847
# 1137     844
# 1094     844
#         ...
# 1330      70
# 1329      70
# 1106      67
# 1176      66
# 1110      56
# 1289      55
# 1298      55
# 1296      55
# 1286      55
# 1288      55
# 1285      55
# 1287      55
# 1294      55
# 1050      35
# 1114      33
# 1331      29
# 2033      28
# 1116      22
# 1117      22
# 1269      18
# 1270      18
# 1268      18
# 1039      14
# 1032      14
# 1279      13
# 1188       8
# 1191       8
# 1192       8
# 1024       6
# 1325       5
# Name: nutrient_id, Length: 198, dtype: int64

# %%
food_nutrients[food_nutrients.food_category_id == 1]
# Out:
#             id  fdc_id  nutrient_id   amount  data_points  derivation_id  \
# 119    2219826  321359         1103    1.800         12.0            1.0
# 120    2219827  321359         1167    0.112         12.0            1.0
# 121    2219828  321359         1175    0.061         12.0            1.0
# 122    2219829  321359         1003    3.350          NaN           49.0
# 123    2219830  321359         1007    0.750         24.0            1.0
# 124    2219831  321359         1166    0.137         12.0            1.0
# 125    2219832  321359         1299    0.019         12.0            1.0
# 126    2219833  321359         1304    0.052         12.0            1.0
# 127    2219834  321359         1314    0.024         12.0            1.0
# 128    2219835  321359         1262    0.049         12.0            1.0
# 129    2219836  321359         1267    0.002         12.0            1.0
# 130    2219837  321359         1261    0.021         12.0            1.0
# ...

# %%
food_nutrients[food_nutrients.description == "TOMATO"]
# Out:
# Empty DataFrame
# Columns: [id, fdc_id, nutrient_id, amount, data_points, derivation_id, min, max, median, footnote, min_year_acquired, data_type, description, food_category_id, publication_date]
# Index: []
